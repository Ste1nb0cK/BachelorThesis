# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.patches import FancyArrowPatch
from matplotlib.patches import Arc
import matplotlib.image as mpimg

#####################################METROLOGY SCHEME##########################################
# Enable LaTeX in Matplotlib
plt.rcParams['text.usetex'] = True
# Setting the font family
plt.rcParams['font.serif'] = 'Times New Roman'
# Setting the mathtext font
plt.rcParams['mathtext.fontset'] = 'cm'
# Create a new figure and axis
 
text_width = 1076.78731/72
fig, ax = plt.subplots(figsize=(text_width, text_width/3))
ax.set_xlim(0, 10)
ax.set_ylim(0, 2)
ax.set_aspect(aspect='auto')
plt.axis('off')
#########
black_code = '#272727'
###Add the rho_0 text
rho_0_x = 0.5
rho_0_y = 1.0
rho_0_text = r'$\rho_{\scriptscriptstyle 0}$'
ax.text(rho_0_x,rho_0_y, rho_0_text, color=black_code, fontsize=30, ha='center', va='center')
###Draw the first line
#Define the initial position of the line
arrow_1_x_in = rho_0_x + 0.2
arrow_1_y_in = rho_0_y
arrow_1_in = (arrow_1_x_in, arrow_1_y_in )
#Define the Final position of the line
arrow_1_x_out = arrow_1_x_in + 0.7
arrow_1_y_out = arrow_1_y_in 
arrow_1_out = (arrow_1_x_out, arrow_1_y_out )
arrow = FancyArrowPatch(arrow_1_in, arrow_1_out, arrowstyle='-', mutation_scale=20, 
                        color=black_code, linewidth=2.5)
ax.add_patch(arrow)
###Draw the first box
#Low left corner
low_left_corner_1 = (arrow_1_x_out, arrow_1_y_out-0.5) 
width_1 = 1
height_1 = 1
rect = patches.Rectangle(low_left_corner_1, width_1, height_1 , linewidth=2.5, edgecolor=black_code, facecolor='none')
ax.add_patch(rect)
###Draw the varespilon_gamma
varespilon_gamma_text = r'$\varepsilon_{\scriptscriptstyle \gamma}$'
varespilon_gamma_x = low_left_corner_1[0]+0.5
varespilon_gamma_y = low_left_corner_1[1]+0.5
ax.text(varespilon_gamma_x,varespilon_gamma_y, varespilon_gamma_text , color=black_code, fontsize=30, ha='center', va='center')
###Draw the second line 
#Define the initial position of the line
arrow_2_x_in = varespilon_gamma_x + 0.5
arrow_2_y_in = varespilon_gamma_y
arrow_2_in = (arrow_2_x_in, arrow_2_y_in )
#Define the Final position of the line
arrow_2_x_out = arrow_2_x_in + 0.8
arrow_2_y_out = arrow_2_y_in
arrow_2_out = (arrow_2_x_out, arrow_2_y_out )
arrow = FancyArrowPatch(arrow_2_in, arrow_2_out, arrowstyle='-', mutation_scale=20, 
                        color=black_code, linewidth=2.5)
ax.add_patch(arrow)
###Draw rho_gamma text
rho_gamma_x = arrow_2_x_out+0.3
rho_gamma_y = arrow_2_y_out
rho_gamma_text = r'$\rho_{\scriptscriptstyle\gamma}$'
ax.text(rho_gamma_x,rho_gamma_y, rho_gamma_text, color=black_code, fontsize=30, ha='center', va='center')
###Draw the third line
#Define the initial position of the arrow
arrow_3_x_in = rho_gamma_x+0.3
arrow_3_y_in = rho_gamma_y
arrow_3_in = (arrow_3_x_in, arrow_3_y_in )
#Define the Final position of the arrow
arrow_3_x_out = arrow_3_x_in + 0.7
arrow_3_y_out = arrow_3_y_in
arrow_3_out = (arrow_3_x_out, arrow_3_y_out )
arrow = FancyArrowPatch(arrow_3_in, arrow_3_out, arrowstyle='-', mutation_scale=20, 
                        color=black_code, linewidth=2.5)
ax.add_patch(arrow)
####Draw the measurement Symbols
##Draw the box
#Low left corner
low_left_corner_1 = (arrow_3_x_out, arrow_3_y_out-0.5) 
width_1 = 1
height_1 = 1
rect = patches.Rectangle(low_left_corner_1, width_1, height_1 , linewidth=2.5, edgecolor=black_code, facecolor='none')
ax.add_patch(rect)

##Draw the circle
center_circle_x = arrow_3_x_out + 0.45
center_circle_y = arrow_3_y_out - 0.1
center_circle = (center_circle_x, center_circle_y)
closed_semicircle = Arc(center_circle, 0.6,0.6 , theta1=0, theta2=180, facecolor='none', edgecolor='black')
ax.add_patch(closed_semicircle)
##Draw the arrow
angle = np.pi/4
end_x = center_circle_x + 0.65 * np.cos(angle)
end_y = center_circle_y+ 0.65 * np.sin(angle)
end_arrow_measurement = (end_x, end_y)
# Draw an arrow at 33 degrees from the center of the semicircle
arrow = FancyArrowPatch((center_circle_x, center_circle_y), end_arrow_measurement, arrowstyle='->', mutation_scale=20, 
                        color=black_code, linewidth=2.5)
ax.add_patch(arrow)
### Draw the fourth line
# Define the initial position of the arrow
arrow_4_x_in = center_circle_x+0.55
arrow_4_y_in = arrow_3_y_in
arrow_4_in = (arrow_4_x_in, arrow_4_y_in )
#Define the Final position of the arrow
arrow_4_x_out = arrow_4_x_in + 1.15
arrow_4_y_out = arrow_4_y_in
arrow_4_out = (arrow_4_x_out, arrow_4_y_out )
arrow = FancyArrowPatch(arrow_4_in, arrow_4_out, arrowstyle='-', mutation_scale=20, 
                        color=black_code, linewidth=2.5)
ax.add_patch(arrow)
###Add the computer
# Load an image
image_path = 'computer_diagram_code.png' 
img = mpimg.imread(image_path)
# Display the image
left_image = 6.1
right_image = 8
bottom_image = -0.1
top_image = 2
ax.imshow(img, extent=[left_image, right_image,bottom_image, top_image])
###Add the final line
# Define the initial position of the arrow
arrow_5_x_in = right_image-0.45
arrow_5_y_in = arrow_3_y_in
arrow_5_in = (arrow_5_x_in, arrow_5_y_in )
#Define the Final position of the arrow
arrow_5_x_out = arrow_5_x_in + 0.7
arrow_5_y_out = arrow_5_y_in
arrow_5_out = (arrow_5_x_out, arrow_5_y_out )
arrow = FancyArrowPatch(arrow_5_in, arrow_5_out, arrowstyle='-', mutation_scale=20, 
                        color=black_code, linewidth=2.5)
ax.add_patch(arrow)
###Final gamma tilda
###Draw rho_gamma text
rho_gamma_tilda_x = arrow_5_x_out+0.2
rho_gamma_y = arrow_2_y_out+0.15
rho_gamma_text = r'$\tilde{\gamma}$'
ax.text(rho_gamma_tilda_x,rho_gamma_y, rho_gamma_text, color=black_code, fontsize=30, ha='center', va='center')
plt.savefig("./Esquema_Estimacion.pdf")

# %%
from matplotlib.patches import Circle
#Define the canvas
fig = plt.figure()
text_width = 1076.78731/72
fig, ax = plt.subplots(figsize=(text_width, text_width/1.618))
ax.set_xlim(0, 25)
ax.set_ylim(0, 10)
ax.set_aspect('equal', adjustable='box')
plt.axis('off')
#Define the circle for the Enviroment
center = (5,5)
radius_sys = 2
radius_env = 3.95
color_env = "#55795A"
circle_env = Circle(center, radius_env, color=color_env, fill=True)
ax.add_patch(circle_env)
#Define the circle for the system
color_sys = "#7286D3"
circle_system = Circle(center, radius_sys, color=color_sys, fill=True)
ax.add_patch(circle_system)
#Add the label of the system and the Enviroment
ax.text(4.3,5, r'$\mathcal{H}_S$', fontsize=45, color="#FFFFFF")
ax.text(4.5,7.5 , r'$\mathcal{H}_E$',   fontsize=45, color='white' )
#Draw the interaction arrows
# Define the initial position of the arrow
theta = np.pi/4
arrow_x_in = 0.6*radius_sys*np.cos(theta)+center[0] 
arrow_y_in = 0.6*radius_sys*np.sin(theta)+center[1]
arrow_in = (arrow_x_in, arrow_y_in)
##Define the Final position of the arrow
arrow_x_out = 0.85*radius_env*np.cos(theta)+center[0]
arrow_y_out = 0.85*radius_env*np.sin(theta)+center[1]
arrow_out = (arrow_x_out, arrow_y_out)
color_arrow = "#D99E30"
arrow = FancyArrowPatch(arrow_in, arrow_out, arrowstyle='<|-|>', mutation_scale=20, 
                        color=color_arrow, linewidth=5)
ax.add_patch(arrow)
##Add the Interaction label 
#add an movement orthogonal to 
radial_movement = 0.3
orthogonal_movement_x = +np.sin(theta)*0.5
orthogonal_movement_y = -np.cos(theta)*0.5
text_interaction_x = arrow_x_in + radial_movement+ orthogonal_movement_x 
text_interaction_y = arrow_y_in + radial_movement+ orthogonal_movement_y
ax.text(text_interaction_x, text_interaction_y, r'$H_{SE}$', fontsize=30, color="#FFFFFF", rotation=52)


############################COMMUTATION DIAGRAM######################33
#Write the H_s
ax.text(10.7,8, r'$\mathcal{H_S}$', fontsize=30)
#Write the H_s \otimes H_E
ax.text(10,2, r'$\mathcal{H_S} \otimes \mathcal{H}_E$', fontsize=25)
##Write the other H_S
ax.text(21,8, r'$\mathcal{H_S}$', fontsize=30)
##Write the other H_s \otimes H_E
ax.text(20,2, r'$\mathcal{H_S} \otimes \mathcal{H}_E$', fontsize=25)
##Draw the connection lines
#From H_S to H_S
arrow1 = FancyArrowPatch((12.7,8.3), (20.7,8.3), arrowstyle='-|>', mutation_scale=20, 
                        color="black", linewidth=5)
ax.add_patch(arrow1)
ax.text( 15,9, r'$\varepsilon_{\scriptscriptstyle\gamma}$', fontsize=55)
##From H_S to H_s \otimes H_j
arrow2 = FancyArrowPatch((11.5,7.5), (11.5,2.8), arrowstyle='-|>', mutation_scale=20, 
                        color="black", linewidth=5)
ax.add_patch(arrow2)
ax.text(11.7,5, r'$\otimes \sigma_{\scriptscriptstyle 0}$', fontsize=35)
##From H_S \otimes H_E to itself
arrow3 = FancyArrowPatch( (13,2.3),(20,2.3) , arrowstyle='-|>', mutation_scale=20, 
                        color="black", linewidth=5)
ax.add_patch(arrow3)
ax.text(15.5,1, r'$U_{ \gamma} \bullet U_{ \gamma}^{\dagger}$', fontsize=25)
##From H_s \otime H_E to H_S
arrow4 = FancyArrowPatch( (21.5,3),(21.5,7.8) , arrowstyle='-|>', mutation_scale=20, 
                        color="black", linewidth=5)
ax.text(22, 5, r"$\mathrm{Tr}_E$", fontsize=30)
ax.add_patch(arrow4)
plt.tight_layout() #Tight, avoid whitespaces
plt.savefig("../images/SE_Diagrams.pdf", dpi=300,  bbox_inches='tight')

# %%
###############################MZ DIAGRAM
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib as mpl

# Create figure and axis
fig, ax = plt.subplots(figsize=(text_width, text_width/3))
# Light Paths
ax.set_xlim(-5, 8)
ax.set_ylim(-1.5, 7)
color_light = "#FF6B6B"
width_light = 5
ax.plot([-3.2, -3.2], [0, 5], color=color_light, linewidth=width_light) # Left Vertical
ax.plot([-3.2, 5], [5, 5], color=color_light, linewidth=width_light ) # Top Horizontal
ax.plot([5, 5], [5, 0], color=color_light, linewidth=width_light ) # Right vertical
ax.plot([-3.2, 5], [0, 0], color=color_light, linewidth=width_light ) #  Bottom horizontal
#Input paths
ax.plot([-4.5, -3.2], [0,0 ], color=color_light, linestyle="--", linewidth=width_light ) #  horizontal
ax.plot([-3.2, -3.2], [-1.5, 0], color=color_light, linestyle="--", linewidth=width_light ) #  vertical
#Output beams 
ax.plot([5, 5], [5,7.5 ], color=color_light, linestyle="--", linewidth=width_light ) #  Vertical
ax.plot([5, 7.5], [5,5 ], color=color_light, linestyle="--", linewidth=width_light ) #  Horizontal
#Beam Splitters
bs_width = 10
color_bs = "#8EEDC7"
ax.plot([-3.75, -2.75], [1*(-3.75--3.2), 1*(-2.75--3.2)], color=color_bs, linewidth=bs_width)
ax.plot([4.4, 5.5], [4.4, 5.5], linewidth=bs_width, color=color_bs)
#Mirrors
color_mirror = "#89ABE3"
ax.plot([-3.75, -2.75], [1*(-3.75--3.2)+5, 1*(-2.75--3.2)+5], color=color_mirror, linewidth=6)
ax.plot([4.45, 5.55], [1*(4.45-5) ,1*(5.55-5) ], color=color_mirror, linewidth=6)
#delimiting lines
delimeters_width = 5
ax.axvline(-2, linestyle="--", color="black", linewidth=delimeters_width)
ax.axvline(4, linestyle="--", color="black", linewidth=delimeters_width)
# Labels
ax.text(-4,0.4, r"$a_1$", fontsize=32) #a1 port
ax.text(-3, -1.2, r"$a_2$", fontsize=32) #a2 port
ax.text(-2.7,0.7, "BS", fontsize=22) #BS1
ax.text(5.7,5.4, "BS", fontsize=22) #BS2
ax.text(-3.8,4.7, "Mirror", fontsize=18, rotation=30) #Mirror1
ax.text(4.9,-1, "Mirror", fontsize=18, rotation=30) #Mirror2
ax.text(-4,6, "Input", fontsize=40, rotation=0) #Input
ax.text(0,6, "Encoding", fontsize=40, rotation=0) #Encoding
ax.text(6.5,6, "Output", fontsize=40, rotation=0) #Output
ax.text(-0.7,-1.2, r"$H = (\omega + \gamma)a_2^{\dagger}a_2 + \omega a_1^{\dagger}a_1 $", fontsize=30, rotation=0) #Output
# Set aspect of the plot to be equal
#ax.set_aspect('equal', adjustable='box')
ax.axis('off')
#ax.grid()
plt.tight_layout() #Tight, avoid whitespaces
plt.savefig("../images/MZ_Diagram.pdf", dpi=300,  bbox_inches='tight')

# %%
##############################Loss Plot
#Functions and Array
t_array = np.linspace(0.0001, 10, 1000)
def Coherent(t):
    return t**2 * np.exp(-t)
def Squeezed(t):
    return  t**2 * (-2*np.exp(t) +np.exp(2*t )+2)/((np.exp(t)-1)*(2*np.exp(t)-2 +np.exp(2* t)))
def Fock(t):
    return t**2 / (np.exp(t) -1 )
#Plot
fig, ax = plt.subplots(figsize=(text_width, text_width/2))
color_coherent = color_arrow
ax.plot(t_array, Coherent(t_array), label="Coherent", color = color_coherent, linewidth=10)
ax.plot(t_array, Squeezed(t_array), label="Squeezed", color= color_light, linewidth=10, linestyle="dashdot")
ax.plot(t_array, Fock(t_array), label="Fock", color=color_env, linewidth=10, linestyle="--")
ax.set_xlabel(r"$\gamma t$", fontsize=40)
ax.set_ylabel(r"$\gamma^2\mathcal{F}(\gammaa)    $", fontsize=40)
ax.set_xlim(0,10)
ax.set_ylim(0,0.6666666)
# Set the line width for the x-axis and y-axis
ax.spines['bottom'].set_linewidth(2)  # Adjust the linewidth as needed
ax.spines['left'].set_linewidth(2)    # Adjust the linewidth as needed
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_xticks([])
ax.set_yticks([])
fig.set_facecolor('#F1F0F1') 
ax.set_facecolor('#F1F0F1') 
ax.axis()
ax.legend(fontsize=30)
plt.tight_layout() #Tight, avoid whitespaces
plt.savefig("../images/Loss_QFI_Plot.pdf", dpi=300,  bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 31
#      29 ax.axis()
#      30 ax.legend(fontsize=30)
# ---> 31 plt.tight_layout() #Tight, avoid whitespaces
#      32 plt.savefig("../images/Loss_QFI_Plot.pdf", dpi=300,  bbox_inches='tight')
#
# File ~/mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py:2587, in tight_layout(pad, h_pad, w_pad, rect)
#    2579 @_copy_docstring_and_deprecators(Figure.tight_layout)
#    2580 def tight_layout(
#    2581     *,
#    (...)
#    2585     rect: tuple[float, float, float, float] | None = None,
#    2586 ) -> None:
# -> 2587     gcf().tight_layout(pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#
# File ~/mambaforge/lib/python3.10/site-packages/matplotlib/figure.py:3540, in Figure.tight_layout(self, pad, h_pad, w_pad, rect)
#    3538 previous_engine = self.get_layout_engine()
# ...
